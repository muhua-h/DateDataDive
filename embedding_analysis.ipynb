# %% [markdown]
# # Analysis for the embeddings

# %%
# Load the embeddings 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from sklearn.manifold import TSNE

# Load the embeddings
trait_df = pd.read_csv('trait_df.csv', index_col=0)
sample_df = pd.read_csv('final_sample.csv')

# %% [markdown]
# # Visualization of samples and traits

# %%
matrix = sample_df.embedding.apply(eval).to_list() + trait_df.embedding.apply(eval).to_list()

# %%
# Convert matrix to a NumPy array
matrix_np = np.array(matrix)

# %%
# Create a t-SNE model and transform the data
tsne = TSNE(n_components=2, perplexity=15, random_state=42, init='random', learning_rate=200)
vis_dims = tsne.fit_transform(matrix_np)

# %%
x = [x for x,y in vis_dims]
y = [y for x,y in vis_dims]

# %%
# Add the t-SNE results to the data frame
sample_df['tsne_x_sample_trait'] = x[:len(sample_df)]
sample_df['tsne_y_sample_trait'] = y[:len(sample_df)]
trait_df['tsne_x_sample_trait'] = x[len(sample_df):]
trait_df['tsne_y_sample_trait'] = y[len(sample_df):]

# %%
# Plot the t-SNE results
fig, ax = plt.subplots()
ax.scatter(sample_df.tsne_x_sample_trait, sample_df.tsne_y_sample_trait, label='Sample')
ax.scatter(trait_df.tsne_x_sample_trait, trait_df.tsne_y_sample_trait, label='Trait')
ax.legend()
plt.show()

# %% [markdown]
# # Visualization of Samples only

# %%
matrix = sample_df.embedding.apply(eval).to_list() 
# Convert matrix to a NumPy array
matrix_np = np.array(matrix)

# Create a t-SNE model and transform the data
tsne = TSNE(n_components=2, perplexity=15, random_state=42, init='random', learning_rate=200)
vis_dims = tsne.fit_transform(matrix_np)

# %%
x = [x for x,y in vis_dims]
y = [y for x,y in vis_dims]

# %%
# Add the t-SNE results to the data frame
sample_df['tsne_x_sample'] = x
sample_df['tsne_y_sample'] = y

# %%
# preview sample_df
sample_df.head(6)
# Out:
#    age          status sex orientation   body_type                 diet  \
# 0   43          single   f    bisexual       curvy  strictly vegetarian
# 1   25  seeing someone   m    bisexual         fit      mostly anything
# 2   36          single   m         gay     average                  NaN
# 3   27       available   f    bisexual       curvy             anything
# 4   42       available   m    straight  overweight    strictly anything
# 5   32  seeing someone   f    bisexual       curvy    mostly vegetarian
#
#        drinks      drugs                          education  \
# 0      rarely        NaN  dropped out of college/university
# 1    socially  sometimes            working on ph.d program
# 2       often      never                                NaN
# 3    socially  sometimes    dropped out of two-year college
# 4       often  sometimes              working on space camp
# 5  very often      never                                NaN
#
#                                   ethnicity  ...  \
# 0                                     white  ...
# 1                                     white  ...
# 2                                     white  ...
# 3  native american, hispanic / latin, white  ...
# 4                                     white  ...
# 5                                     white  ...
#
#                             you_should_message_me_if  \
# 0  if you want to be my friend who i can spend ti...
# 1  you feel like it. i promise i won't bite. but ...
# 2  you are younger, slim to athletic, smooth to s...
# 3  you're good in the sack, can respect my marria...
# 4  we're a 99% match. i'm willing to listen if we...
# 5  *you'd like to discuss my future breakdancing ...
#
#                                       merged_profile cleaned_religion  \
# 0  june is turning out to be crazy because my new...          atheism
# 1  well, i'm in a relationship now. i'm keeping m...          atheism
# 2  i have a tempered, reasonable way of thinking....          atheism
# 3  i'm an adult actress who has recently started ...          atheism
# 4  i'm a 42-year-old divorced father of two boys ...          atheism
# 5  edit: my life is pretty full right now. i've b...          atheism
#
#   seriousness_degree   belief  \
# 0                4.0  atheism
# 1                4.0  atheism
# 2                4.0  atheism
# 3                4.0  atheism
# 4                4.0  atheism
# 5                4.0  atheism
#
#                                            embedding tsne_x_sample_trait  \
# 0  [0.010035235434770584, -0.04175163060426712, -...            2.561301
# 1  [-0.0027743300888687372, -0.023896805942058563...           16.121382
# 2  [0.002556383376941085, -0.0058164591901004314,...            0.420033
# 3  [0.0430191308259964, -0.010054229758679867, -0...           -7.661303
# 4  [0.017534952610731125, -0.03899239003658295, -...            2.397567
# 5  [0.020217396318912506, -0.019407430663704872, ...           23.523518
#
#   tsne_y_sample_trait tsne_x_sample tsne_y_sample
# 0            6.352235      0.617637    -10.110859
# 1           16.964415    -41.818817     32.768166
# 2            9.085909      9.759092    -20.171118
# 3           -1.654478     26.133169    -21.815580
# 4           11.375900      2.004565    -22.876705
# 5            9.143626    -40.931484    -24.244244
#
# [6 rows x 38 columns]

# %%
# preview trait_df
trait_df.head(6)
# Out:
#                                                                     embedding  \
# trait
# Confidence                  [0.0030066920444369316, 0.023917969316244125, ...
# Kindness and Compassion     [0.0016048743855208158, -0.021392831578850746,...
# Sense of Humor              [-0.004063126631081104, 0.007852434180676937, ...
# Intelligence and Education  [0.01945118047297001, 0.0042092157527804375, -...
# Emotional Stability         [0.007982526905834675, -0.008557992056012154, ...
# Physical Attractiveness     [0.014652966521680355, -0.005493862088769674, ...
#
#                             tsne_x_sample_trait  tsne_y_sample_trait
# trait
# Confidence                           -25.159050            -5.460770
# Kindness and Compassion              -23.218712           -13.093249
# Sense of Humor                       -19.629057            -0.813614
# Intelligence and Education           -28.216866            -3.016228
# Emotional Stability                  -25.884626            -6.620493
# Physical Attractiveness              -30.245287            -5.528705

# %%
# Plot the t-SNE results
import seaborn as sns

# Check if the specified columns are present in the dataframe
required_columns = ['tsne_x_sample', 'tsne_y_sample', 'sex', 'cleaned_religion']
missing_columns = [col for col in required_columns if col not in sample_df.columns]

# If no columns are missing, proceed with plotting
if not missing_columns:
    # Set the style of the plot
    sns.set(style="whitegrid")

    # Create a scatter plot
    plt.figure(figsize=(10, 8))
    scatter = sns.scatterplot(x='tsne_x_sample', y='tsne_y_sample', 
                              style='sex', hue='cleaned_religion', 
                              data=sample_df, palette='Set1', s=100)

    # Add a legend and title
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.title('t-SNE by Sex and Religion')

    # Show the plot
    plt.show()
else:
    missing_columns

# %% [markdown]
# # Compare cosince similarity between samples and traits

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate the cosine similarity between the samples and traits
sample_trait_similarity = cosine_similarity(sample_df.embedding.apply(eval).to_list(), trait_df.embedding.apply(eval).to_list())

# %%
sample_trait_similarity.shape
# Out:
# (105, 20)

# %%
# create a dataframe for sample_trait_similarity where the index is the sample_id and the columns are the trait_id
sample_trait_similarity_df = pd.DataFrame(sample_trait_similarity, index=sample_df.index, columns=trait_df.index)

# Display the first few rows of the data frame
sample_trait_similarity_df
# Out:
# trait  Confidence  Kindness and Compassion  Sense of Humor  \
# 0        0.099433                 0.196504        0.261465
# 1        0.134532                 0.097457        0.193962
# 2        0.138342                 0.138725        0.211848
# 3        0.145015                 0.117514        0.218881
# 4        0.179454                 0.098656        0.182225
# ..            ...                      ...             ...
# 100      0.089907                 0.153825        0.147698
# 101      0.096706                 0.167971        0.239644
# 102      0.116315                 0.086029        0.121503
# 103      0.146767                 0.092665        0.196320
# 104      0.159538                 0.207090        0.374170
#
# trait  Intelligence and Education  Emotional Stability  \
# 0                        0.213190             0.141992
# 1                        0.105638             0.066324
# 2                        0.189166             0.154527
# 3                        0.117847             0.127183
# 4                        0.167229             0.131638
# ..                            ...                  ...
# 100                      0.147924             0.057979
# 101                      0.206817             0.133217
# 102                      0.128248             0.061601
# 103                      0.083992             0.090144
# 104                      0.167517             0.167592
#
# trait  Physical Attractiveness  Ambition and Passion  \
# 0                     0.213757              0.212865
# 1                     0.131314              0.094809
# 2                     0.267990              0.158051
# 3                     0.288851              0.153706
# 4                     0.239598              0.109072
# ..                         ...                   ...
# 100                   0.066270              0.115898
# 101                   0.108322              0.203205
# 102                   0.102481              0.127027
# 103                   0.085291              0.156447
# 104                   0.141834              0.176886
#
# trait  Compatibility and Shared Values  Communication Skills  \
# 0                             0.260684              0.130860
# 1                             0.059870              0.187128
# 2                             0.212880              0.160960
# 3                             0.180975              0.112770
# 4                             0.331929              0.128634
# ..                                 ...                   ...
# 100                           0.104185              0.078759
# 101                           0.180088              0.154853
# 102                           0.078528              0.170100
# 103                           0.075699              0.099150
# 104                           0.163143              0.207940
#
# trait  Generosity and Charity  \
# 0                    0.109135
# 1                    0.041692
# 2                    0.058436
# 3                    0.126956
# 4                    0.043348
# ..                        ...
# 100                  0.150065
# 101                  0.121085
# 102                  0.015491
# 103                  0.060474
# 104                  0.182858
#
# trait  Spiritual Commitment and Shared Religious Practices  \
# 0                                               0.135104
# 1                                               0.060186
# 2                                               0.082286
# 3                                               0.093120
# 4                                               0.122104
# ..                                                   ...
# 100                                             0.180065
# 101                                             0.132605
# 102                                             0.045491
# 103                                             0.050544
# 104                                             0.072643
#
# trait  Moral Integrity and Respect for Tradition  Family Values  \
# 0                                       0.135608       0.104665
# 1                                       0.044415      -0.002052
# 2                                       0.088067       0.046777
# 3                                       0.156288       0.153626
# 4                                       0.102087       0.069727
# ..                                           ...            ...
# 100                                     0.166493       0.105198
# 101                                     0.107198       0.098002
# 102                                     0.032195       0.055345
# 103                                     0.023324       0.085918
# 104                                     0.059681       0.079534
#
# trait  Patience and Forgiveness  Humility and Modesty  Openness to Growth  \
# 0                      0.146181              0.132220            0.181319
# 1                      0.065894              0.081691            0.128832
# 2                      0.121898              0.145371            0.201125
# 3                      0.099137              0.179056            0.135315
# 4                      0.079158              0.109573            0.169127
# ..                          ...                   ...                 ...
# 100                    0.086568              0.165093            0.135347
# 101                    0.118831              0.085647            0.177149
# 102                    0.090845              0.066852            0.138668
# 103                    0.095597              0.126712            0.144459
# 104                    0.117879              0.166576            0.147108
#
# trait  Purity and Chastity  High Social Status and Wealth  Masculinity  \
# 0                 0.126247                       0.174401     0.129114
# 1                 0.029192                       0.057414     0.056419
# 2                 0.074878                       0.133860     0.145874
# 3                 0.152719                       0.165908     0.185834
# 4                 0.094610                       0.144264     0.062505
# ..                     ...                            ...          ...
# 100               0.182398                       0.156896     0.072492
# 101               0.059676                       0.155952     0.050888
# 102               0.058320                       0.056841     0.055469
# 103               0.172979                       0.066378     0.084826
# 104               0.058184                       0.188088     0.076888
#
# trait  Femininity
# 0        0.168873
# 1        0.085450
# 2        0.131375
# 3        0.255579
# 4        0.101531
# ..            ...
# 100      0.090565
# 101      0.082257
# 102      0.070183
# 103      0.151641
# 104      0.140090
#
# [105 rows x 20 columns]

# %%
# concatenate the sample_df and sample_trait_similarity_df
sample_df = pd.concat([sample_df, sample_trait_similarity_df], axis=1)

# Display the first few rows of the data frame
sample_df.head()
# Out:
#    age          status sex orientation   body_type                 diet  \
# 0   43          single   f    bisexual       curvy  strictly vegetarian
# 1   25  seeing someone   m    bisexual         fit      mostly anything
# 2   36          single   m         gay     average                  NaN
# 3   27       available   f    bisexual       curvy             anything
# 4   42       available   m    straight  overweight    strictly anything
#
#      drinks      drugs                          education  \
# 0    rarely        NaN  dropped out of college/university
# 1  socially  sometimes            working on ph.d program
# 2     often      never                                NaN
# 3  socially  sometimes    dropped out of two-year college
# 4     often  sometimes              working on space camp
#
#                                   ethnicity  ...  \
# 0                                     white  ...
# 1                                     white  ...
# 2                                     white  ...
# 3  native american, hispanic / latin, white  ...
# 4                                     white  ...
#
#    Spiritual Commitment and Shared Religious Practices  \
# 0                                           0.135104
# 1                                           0.060186
# 2                                           0.082286
# 3                                           0.093120
# 4                                           0.122104
#
#    Moral Integrity and Respect for Tradition Family Values  \
# 0                                   0.135608      0.104665
# 1                                   0.044415     -0.002052
# 2                                   0.088067      0.046777
# 3                                   0.156288      0.153626
# 4                                   0.102087      0.069727
#
#   Patience and Forgiveness Humility and Modesty Openness to Growth  \
# 0                 0.146181             0.132220           0.181319
# 1                 0.065894             0.081691           0.128832
# 2                 0.121898             0.145371           0.201125
# 3                 0.099137             0.179056           0.135315
# 4                 0.079158             0.109573           0.169127
#
#   Purity and Chastity High Social Status and Wealth Masculinity Femininity
# 0            0.126247                      0.174401    0.129114   0.168873
# 1            0.029192                      0.057414    0.056419   0.085450
# 2            0.074878                      0.133860    0.145874   0.131375
# 3            0.152719                      0.165908    0.185834   0.255579
# 4            0.094610                      0.144264    0.062505   0.101531
#
# [5 rows x 78 columns]

# %%
# create a sample_df for men and women 
sample_df_m = sample_df[sample_df['sex'] == 'm']
sample_df_f = sample_df[sample_df['sex'] == 'f']

# print the shape of the sample_df_m and sample_df_f
sample_df_m.shape, sample_df_f.shape
# Out:
# ((51, 78), (54, 78))

# %%
# Split the data based on the 'sex' category
female_df = sample_df_f.groupby('cleaned_religion').apply(lambda x: x.iloc[:, -20:].mean())
male_df = sample_df_m.groupby('cleaned_religion').apply(lambda x: x.iloc[:, -20:].mean())

# %%
# Calculate the global minimum and maximum of the dataframes
vmin = min(female_df.min().min(), male_df.min().min())
vmax = max(female_df.max().max(), male_df.max().max())

# Create heatmaps for both subsets
plt.figure(figsize=(20, 10))

# Heatmap for 'f'
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
sns.heatmap(female_df, cmap='coolwarm', annot=True, fmt=".2f", vmin=vmin, vmax=vmax)
plt.title('Heatmap for Females')
plt.yticks(rotation=0)  # rotate the y-axis labels for left plot

# Heatmap for 'm'
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
sns.heatmap(male_df, cmap='coolwarm', annot=True, fmt=".2f", vmin=vmin, vmax=vmax)
plt.title('Heatmap for Males')
plt.yticks(rotation=0)  # rotate the y-axis labels for right plot

plt.tight_layout()
plt.savefig('heatmap.png')
plt.show()
